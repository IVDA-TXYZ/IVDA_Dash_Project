# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Datasets/Clean_Dataset.csv')

# %%
print(df.columns)
print([(i, type(i)) for i in df.iloc[0]])

continues_attributes = ['duration_ms', 'year',
       'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo']
categorical_attributes = ['artist', 'song', 'explicit', 'genre']

['x, y, song, art']
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'artist', 'song', 'duration_ms',
#        'explicit', 'year', 'popularity', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'genre'],
#       dtype='object')
# [(0, <class 'numpy.int64'>), (0, <class 'numpy.int64'>), ('Britney Spears', <class 'str'>), ('Oops!...I Did It Again', <class 'str'>), (211160, <class 'numpy.int64'>), (0, <class 'numpy.int64'>), (2000, <class 'numpy.int64'>), (77, <class 'numpy.int64'>), (0.751, <class 'numpy.float64'>), (0.834, <class 'numpy.float64'>), (1, <class 'numpy.int64'>), (-5.444, <class 'numpy.float64'>), (0, <class 'numpy.int64'>), (0.0437, <class 'numpy.float64'>), (0.3, <class 'numpy.float64'>), (1.77e-05, <class 'numpy.float64'>), (0.355, <class 'numpy.float64'>), (0.894, <class 'numpy.float64'>), (95.053, <class 'numpy.float64'>), ('pop', <class 'str'>)]
# ['x, y, song, art']

# %%
min(df.year), max(df.year)
# Out:
# (1998, 2020)

# %%
df[categorical_attributes]
# Out:
#               artist                                    song  explicit  \
# 0     Britney Spears                  Oops!...I Did It Again         0
# 1          blink-182                    All The Small Things         0
# 2         Faith Hill                                 Breathe         0
# 3           Bon Jovi                            It's My Life         0
# 4             *NSYNC                             Bye Bye Bye         0
# ...              ...                                     ...       ...
# 1800  Jonas Brothers                                  Sucker         0
# 1801    Taylor Swift                            Cruel Summer         0
# 1802    Blanco Brown                              The Git Up         0
# 1803       Sam Smith  Dancing With A Stranger (with Normani)         0
# 1804     Post Malone                                 Circles         0
#
#                  genre
# 0                  pop
# 1            rock, pop
# 2         pop, country
# ...

# %%
dff = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')

# %%
dff.head()
# Out:
#   Country Name                                     Indicator Name  Year  \
# 0   Arab World                Agriculture, value added (% of GDP)  1962
# 1   Arab World             CO2 emissions (metric tons per capita)  1962
# 2   Arab World  Domestic credit provided by financial sector (...  1962
# 3   Arab World        Electric power consumption (kWh per capita)  1962
# 4   Arab World       Energy use (kg of oil equivalent per capita)  1962
#
#        Value
# 0        NaN
# 1   0.760996
# 2  18.168690
# 3        NaN
# 4        NaN

# %%
df[df['duration_ms'].between(113e3, 484e3, inclusive='both')]
# Out:
#       Unnamed: 0.1  Unnamed: 0          artist  \
# 0                0           0  Britney Spears
# 1                1           1       blink-182
# 2                2           2      Faith Hill
# 3                3           3        Bon Jovi
# 4                4           4          *NSYNC
# ...            ...         ...             ...
# 1800          1800        1995  Jonas Brothers
# 1801          1801        1996    Taylor Swift
# 1802          1802        1997    Blanco Brown
# 1803          1803        1998       Sam Smith
# 1804          1804        1999     Post Malone
#
#                                         song  duration_ms  explicit  year  \
# 0                     Oops!...I Did It Again       211160         0  2000
# 1                       All The Small Things       167066         0  1999
# 2                                    Breathe       250546         0  1999
# 3                               It's My Life       224493         0  2000
# ...

# %%
dff = df.copy()
print(len(df))
dff = dff.drop(0)
len(dff)
# Out:
# 1805
# 1804

# %%
for s in list(df.columns):
    print("dff = dff[dff['{}'].between({}_range[0], {}_range[1], inclusive='both')]".format(s, s, s))
# Out:
# dff = dff[dff['Unnamed: 0.1'].between(Unnamed: 0.1_range[0], Unnamed: 0.1_range[1], inclusive='both')]
# dff = dff[dff['Unnamed: 0'].between(Unnamed: 0_range[0], Unnamed: 0_range[1], inclusive='both')]
# dff = dff[dff['artist'].between(artist_range[0], artist_range[1], inclusive='both')]
# dff = dff[dff['song'].between(song_range[0], song_range[1], inclusive='both')]
# dff = dff[dff['duration_ms'].between(duration_ms_range[0], duration_ms_range[1], inclusive='both')]
# dff = dff[dff['explicit'].between(explicit_range[0], explicit_range[1], inclusive='both')]
# dff = dff[dff['year'].between(year_range[0], year_range[1], inclusive='both')]
# dff = dff[dff['popularity'].between(popularity_range[0], popularity_range[1], inclusive='both')]
# dff = dff[dff['danceability'].between(danceability_range[0], danceability_range[1], inclusive='both')]
# dff = dff[dff['energy'].between(energy_range[0], energy_range[1], inclusive='both')]
# ...

# %%
for s in list(df.columns):
    print("             dcc.RangeSlider(\n                   min=df['{}'].min(),\n                   max=df['{}'].max(),\n                   step=None,\n                    value=[df['{}'].min(),\n                   df['{}'].max()],\n                  id='{}_selector',\n                 ),".format(s, s, s, s, s))
# Out:
#              dcc.RangeSlider(
#                    min=df['Unnamed: 0.1'].min(),
#                    max=df['Unnamed: 0.1'].max(),
#                    step=None,
#                     value=[df['Unnamed: 0.1'].min(),
#                    df['Unnamed: 0.1'].max()],
#                   id='Unnamed: 0.1_selector',
#                  ),
#              dcc.RangeSlider(
#                    min=df['Unnamed: 0'].min(),
#                    max=df['Unnamed: 0'].max(),
#                    step=None,
#                     value=[df['Unnamed: 0'].min(),
#                    df['Unnamed: 0'].max()],
#                   id='Unnamed: 0_selector',
#                  ),
#              dcc.RangeSlider(
#                    min=df['artist'].min(),
#                    max=df['artist'].max(),
#                    step=None,
#                     value=[df['artist'].min(),
#                    df['artist'].max()],
#                   id='artist_selector',
#                  ),
# ...

# %%
for s in list(df.columns):
    print("[Input('{}_selector', 'value')],".format(s))
# Out:
# [Input('Unnamed: 0.1_selector', 'value')],
# [Input('Unnamed: 0_selector', 'value')],
# [Input('artist_selector', 'value')],
# [Input('song_selector', 'value')],
# [Input('duration_ms_selector', 'value')],
# [Input('explicit_selector', 'value')],
# [Input('year_selector', 'value')],
# [Input('popularity_selector', 'value')],
# [Input('danceability_selector', 'value')],
# [Input('energy_selector', 'value')],
# [Input('key_selector', 'value')],
# [Input('loudness_selector', 'value')],
# [Input('mode_selector', 'value')],
# [Input('speechiness_selector', 'value')],
# [Input('acousticness_selector', 'value')],
# [Input('instrumentalness_selector', 'value')],
# [Input('liveness_selector', 'value')],
# [Input('valence_selector', 'value')],
# [Input('tempo_selector', 'value')],
# [Input('genre_selector', 'value')],

# %%
for s in list(df.columns):
    print("{}_range,".format(s))
# Out:
# Unnamed: 0.1_range,
# Unnamed: 0_range,
# artist_range,
# song_range,
# duration_ms_range,
# explicit_range,
# year_range,
# popularity_range,
# danceability_range,
# energy_range,
# key_range,
# loudness_range,
# mode_range,
# speechiness_range,
# acousticness_range,
# instrumentalness_range,
# liveness_range,
# valence_range,
# tempo_range,
# genre_range,

# %%
df.groupby(by='year').count()
# Out:
#       Unnamed: 0.1  Unnamed: 0  artist  song  duration_ms  explicit  \
# year
# 1998             1           1       1     1            1         1
# 1999            38          38      38    38           38        38
# 2000            69          69      69    69           69        69
# 2001           104         104     104   104          104       104
# 2002            85          85      85    85           85        85
# 2003            89          89      89    89           89        89
# 2004            94          94      94    94           94        94
# 2005            97          97      97    97           97        97
# 2006            87          87      87    87           87        87
# 2007            87          87      87    87           87        87
# 2008            89          89      89    89           89        89
# 2009            81          81      81    81           81        81
# 2010            96          96      96    96           96        96
# ...

# %%
s = [0, ]
df
# df[df['explicit'].isin(list(s))]
# Out:
#       Unnamed: 0.1  Unnamed: 0          artist  \
# 0                0           0  Britney Spears
# 1                1           1       blink-182
# 2                2           2      Faith Hill
# 3                3           3        Bon Jovi
# 4                4           4          *NSYNC
# ...            ...         ...             ...
# 1800          1800        1995  Jonas Brothers
# 1801          1801        1996    Taylor Swift
# 1802          1802        1997    Blanco Brown
# 1803          1803        1998       Sam Smith
# 1804          1804        1999     Post Malone
#
#                                         song  duration_ms  explicit  year  \
# 0                     Oops!...I Did It Again       211160         0  2000
# 1                       All The Small Things       167066         0  1999
# 2                                    Breathe       250546         0  1999
# 3                               It's My Life       224493         0  2000
# ...
